# %%
import epw_columns
import pandas as pd
import glob
epwFiles = glob.glob('./*.epw')

# %%
mesFichiers = {}
for file in epwFiles:
    name = file.split('\\')[-1].split('.epw')[0]
    mesFichiers[name] = pd.read_csv(file, names = epw_columns.get(), skiprows = 8)
    try:mesFichiers[name].index = pd.date_range(start = '2021-01-01 01:00:00', end = '2022-01-01 00:00:00', freq = '1h')
    except:mesFichiers[name].index = pd.date_range(start = '2021-01-01 01:00:00', end = '2022-01-02 00:00:00', freq = '1h')

# %%
'30 Rue du Faubourg Poissonnière, 75010 Paris',
'80 Av. Victor Cresson, 92130 Issy-les-Moulineaux',
'102 Av. du Général de Gaulle, 94160 Saint-Mandé',
'55 Avenue Caffin, 94210 Saint-Maur-des-Fossés',
'81 Avenue Louis Roche, 92230 Gennevilliers'
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
sns.set(font_scale = 1.5)
sns.set_style("ticks")
fig, ax0 = plt.subplots(1,1, figsize = (8,6))
colorListe  = sns.color_palette("hls", len(mesFichiers.keys()))
for file, c in zip(mesFichiers.keys(),colorListe):
    if len(file) ==2:
        if 'RCP85' and '2030' in file[0]:
            sns.histplot(mesFichiers[file[0]]['Dry Bulb Temperature'], ax=ax0, label = file[0], kde = True)
        else:pass
    else:
        if '81 Avenue Louis Roche, 92230 Gennevilliers' in file:
            sns.kdeplot(data = mesFichiers[file], x="Dry Bulb Temperature", ax=ax0, label = file, color = c)
        
        elif '30 Rue du Faubourg Poissonnière, 75010 Paris' in file:
            sns.kdeplot(data = mesFichiers[file], x="Dry Bulb Temperature", ax=ax0, label = file, color = c)
        else:pass
plt.legend(bbox_to_anchor = (1,1))
plt.ylabel('T [°C]')
# Out:
# Text(0, 0.5, 'T [°C]')

# %%
mesFichiers['102 Av. du Général de Gaulle, 94160 Saint-Mandé_Paris_Montsouris-hour-RCP26_2030']
# Out:
#                      Year  Month  Day  Hour  Minute  \
# 2021-01-01 01:00:00  2030      1    1     1      60
# 2021-01-01 02:00:00  2030      1    1     2      60
# 2021-01-01 03:00:00  2030      1    1     3      60
# 2021-01-01 04:00:00  2030      1    1     4      60
# 2021-01-01 05:00:00  2030      1    1     5      60
# ...                   ...    ...  ...   ...     ...
# 2021-12-31 20:00:00  2030     12   31    20      60
# 2021-12-31 21:00:00  2030     12   31    21      60
# 2021-12-31 22:00:00  2030     12   31    22      60
# 2021-12-31 23:00:00  2030     12   31    23      60
# 2022-01-01 00:00:00  2030     12   31    24      60
#
#                                 Data Source and Uncertainty Flags  \
# 2021-01-01 01:00:00  *?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?
# 2021-01-01 02:00:00  *?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?
# 2021-01-01 03:00:00  *?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?
# 2021-01-01 04:00:00  *?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?*?
# ...

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]
